# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
import autokeras as ak
import tensorflow as tf
import random

# %%
random.seed(123)
np.random.seed(123)
tf.random.set_seed(123)

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Data Loading and Preprocessing

# %%
Max_log_core_ML   = pd.read_csv("core_interval_ML_maxhamish.csv")
Kom_log_core_ML   = pd.read_csv("core_interval_ML_komie.csv")
Adam_log_core_ML  = pd.read_csv("core_interval_ML_mxadam.csv")

# %%
Max_log_core_ML
# Out:
#         Top   Bottom    Median    TOC     S1     S2    S3   Tmax      HI  \
# 0   2955.50  2955.60  2955.550  3.435  0.884  0.364  0.29    NaN   10.60
# 1   2965.00  2965.10  2965.050  5.241  0.600  0.210  0.31    NaN    4.01
# 2   2965.20  2965.26  2965.230  2.302  0.450  0.180  0.22  304.0    7.82
# 3   2967.50  2967.60  2967.550  4.190  0.270  0.130  0.28    NaN    3.10
# 4   2968.30  2968.37  2968.335  3.604  0.700  0.250  0.24    NaN    6.94
# ..      ...      ...       ...    ...    ...    ...   ...    ...     ...
# 82  3077.98  3078.09  3078.035  1.103  0.450  0.130  0.31    NaN   11.79
# 83  3080.50  3080.60  3080.550  0.407  0.550  0.230  0.22  354.0   56.51
# 84  3082.97  3083.07  3083.020  0.027  0.090  0.070  0.21  512.0  259.26
# 85  3085.95  3086.05  3086.000  0.043  0.090  0.080  0.22  509.0  186.05
# 86  3090.00  3090.12  3090.060  0.252  0.260  0.140  0.22  367.0   55.56
#
#         OI  S2/S3  S1/TOC*100    PI       AF10         AF20        AF30  \
# ...

# %%
Kom_log_core_ML
# Out:
#         TOP     BASE   TOC    S1    S2    S3  TMAX  HI  OI    MEDIAN  \
# 0   2224.50  2224.60  3.12  1.72  1.34  0.10   325  43   3  2224.550
# 1   2234.00  2234.10  3.09  1.00  1.13  0.08   331  37   3  2234.050
# 2   2244.05  2244.15  4.47  1.88  1.83  0.20   333  41   4  2244.100
# 3   2254.43  2254.51  5.26  1.90  1.93  0.10   334  37   2  2254.470
# 4   2264.50  2264.60  0.34  0.09  0.16  0.27   328  46  80  2264.550
# 5   2274.00  2274.10  1.40  0.42  0.53  0.12   314  38   9  2274.050
# 6   2284.60  2284.69  0.43  0.08  0.07  0.16   330  16  37  2284.645
# 7   2294.50  2294.60  0.46  0.04  0.05  0.18   338  11  39  2294.550
# 8   2304.49  2304.59  0.93  0.50  0.45  0.18   314  48  19  2304.540
# 9   2315.00  2315.11  1.49  0.48  0.46  0.18   318  31  12  2315.055
# 10  2325.00  2325.10  0.86  0.20  0.26  0.15   324  30  18  2325.050
# 11  2344.93  2345.04  5.65  4.05  2.49  0.38   330  44   7  2344.985
# 12  2355.06  2355.16  0.87  0.66  0.55  0.07   324  63   8  2355.110
# ...

# %%
Adam_log_core_ML
# Out:
#     Top(depth)  Bottom(depth)     HI     OI    S1    S2    S3   TMAX  \
# 0      2719.59        2719.68   46.0   22.0  1.21  1.19  0.56  367.0
# 1      2730.44        2730.54   49.0   23.0  1.31  1.28  0.60  362.0
# 2      2744.58        2744.67   36.0   15.0  2.41  1.51  0.62  370.0
# 3      2755.80        2755.89   20.0   12.0  0.92  0.75  0.44  353.0
# 4      2766.57        2766.67   17.0    9.0  0.71  0.62  0.32  357.0
# 5      2775.61        2775.71   47.0   18.0  3.15  1.38  0.54  376.0
# 6      2786.13        2786.23   14.0    7.0  0.54  0.53  0.27  357.0
# 7      2796.32        2796.42  123.0  123.0  0.71  0.53  0.53  363.0
# 8      2813.75        2813.85   31.0   39.0  0.53  0.36  0.46  364.0
# 9      2824.25        2824.34   45.0   36.0  0.75  0.43  0.34  366.0
# 10     2833.56        2833.66   25.0   16.0  0.17  0.35  0.23  365.0
# 11     2843.70        2843.79   19.0   17.0  0.29  0.27  0.25  361.0
# 12     2853.91        2854.00   34.0   21.0  0.68  0.56  0.34  369.0
# ...

# %%
# Max = Max_log_core_ML.filter(['S1', 'S2', 'S3', 'HI','OI','PI','DPHI_DOL','DPHI_LIM','DPHI_SAN'
#                               ,'NPHI_DOL','NPHI_LIM','NPHI_SAN','NPOR_DOL','NPOR_LIM','NPOR_SAN'
#                               ,'HBHK','HURA','HTHO','RHOM','Vp','Vs','AI','SI','TOC'])
# Max = Max_log_core_ML.filter(['S1', 'S2', 'S3', 'HI','OI','PI','DPHI_DOL','DPHI_LIM','DPHI_SAN'
#                               ,'NPHI_DOL','NPHI_LIM','HBHK','HURA','HTHO','RHOM','GR','Vp','Vs','AI','SI','TOC'])

# HBHK excluded since lots of NaN value in the core sample interval
Max = Max_log_core_ML.filter(['Median','DPHI_DOL','DPHI_LIM','DPHI_SAN'
                              ,'NPHI_DOL','NPHI_LIM','HURA','HTHO','RHOM','GR','Vp','Vs','AI','SI','TOC'])
Max = Max.dropna()
Max['Well'] = 'Maxhamish'
Max.rename(columns={"Median" : "MEDIAN","HURA": "U", "HTHO": "TH", "RHOM" : "RhoB", }, inplace=True)
Max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 0 to 84
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MEDIAN    85 non-null     float64
#  1   DPHI_DOL  85 non-null     float64
#  2   DPHI_LIM  85 non-null     float64
#  3   DPHI_SAN  85 non-null     float64
#  4   NPHI_DOL  85 non-null     float64
#  5   NPHI_LIM  85 non-null     float64
#  6   U         85 non-null     float64
#  7   TH        85 non-null     float64
#  8   RhoB      85 non-null     float64
#  9   GR        85 non-null     float64
#  10  Vp        85 non-null     float64
#  11  Vs        85 non-null     float64
#  12  AI        85 non-null     float64
#  13  SI        85 non-null     float64
#  14  TOC       85 non-null     float64
#  15  Well      85 non-null     object
# dtypes: float64(15), object(1)
# memory usage: 11.3+ KB

# %%
# Max.isnull().any()
# Max.isna().sum()

# %%
# Kom = Kom_log_core_ML.filter(['S1','S2','S3','HI','OI','PI','PZDL','PZLS','PZSS',
#                              'CNCDL','CNCLS','K','U', 'TH','ZDEN','GR','Vp','Vs','AI','SI','TOC'])
Kom = Kom_log_core_ML.filter(['MEDIAN','PZDL','PZLS','PZSS',
                             'CNCDL','CNCLS','U', 'TH','ZDEN','GR','Vp','Vs','AI','SI','TOC'])
Kom = Kom.dropna()
Kom['Well'] = 'Komie'
Kom.rename(columns={"PZDL": "DPHI_DOL", "PZLS": "DPHI_LIM", "PZSS" : "DPHI_SAN",
                    "CNCDL" : "NPHI_DOL", "CNCLS" : "NPHI_LIM", "ZDEN" : "RhoB",}, inplace=True)
Kom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17 entries, 0 to 16
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MEDIAN    17 non-null     float64
#  1   DPHI_DOL  17 non-null     float64
#  2   DPHI_LIM  17 non-null     float64
#  3   DPHI_SAN  17 non-null     float64
#  4   NPHI_DOL  17 non-null     float64
#  5   NPHI_LIM  17 non-null     float64
#  6   U         17 non-null     float64
#  7   TH        17 non-null     float64
#  8   RhoB      17 non-null     float64
#  9   GR        17 non-null     float64
#  10  Vp        17 non-null     float64
#  11  Vs        17 non-null     float64
#  12  AI        17 non-null     float64
#  13  SI        17 non-null     float64
#  14  TOC       17 non-null     float64
#  15  Well      17 non-null     object
# dtypes: float64(15), object(1)
# memory usage: 2.3+ KB

# %%
# Kom.isna().sum()

# %%
# Adam = Adam_log_core_ML.filter(['S1','S2','S3','HI','OI','PI','DPHI_DOL','DPHI_LIM','DPHI_SAN',
#                                'NPOR_DOL','NPOR_LIM','NPOR_SAN','HFK','HURA','HTHO','ECGR','Vp','Vs','AI','SI','TOC'])
Adam = Adam_log_core_ML.filter(['MEDIAN','DPHI_DOL','DPHI_LIM','DPHI_SAN',
                               'NPOR_DOL','NPOR_LIM','HURA','HTHO','RHOZ','ECGR','Vp','Vs','AI','SI','TOC'])
Adam = Adam.dropna()
Adam['Well'] = 'MxAdam'
Adam.rename(columns={"NPOR_DOL" : "NPHI_DOL", "NPOR_LIM" : "NPHI_LIM", "HURA" : "U", "HTHO" : "TH","RHOZ" : "RhoB" , "ECGR" : "GR"}, inplace=True)

Adam
# Out:
#       MEDIAN  DPHI_DOL  DPHI_LIM  DPHI_SAN  NPHI_DOL  NPHI_LIM        U  \
# 0   2719.635    0.1085    0.0355    0.0004    0.1699    0.1917   6.3451
# 1   2730.490    0.1307    0.0596    0.0254    0.1060    0.1202   8.2034
# 2   2744.625    0.1433    0.0732    0.0395    0.0550    0.0644   7.8821
# 3   2755.845    0.1754    0.1079    0.0755    0.0679    0.0781  19.9152
# 4   2766.620    0.2028    0.1375    0.1062    0.0874    0.0996  16.7217
# 5   2775.660    0.1763    0.1088    0.0764    0.0702    0.0812   9.4899
# 6   2786.180    0.1675    0.0993    0.0666    0.1518    0.1713  16.1661
# 7   2796.370    0.0398   -0.0388   -0.0766    0.1250    0.1414   1.6146
# 8   2813.800    0.0868    0.0120   -0.0239    0.1144    0.1295   2.7682
# 9   2824.295    0.0652   -0.0114   -0.0482    0.0375    0.0451   1.1134
# 10  2833.610    0.1126    0.0399    0.0050    0.0778    0.0893   2.9948
# 11  2843.745    0.0955    0.0214   -0.0142    0.1094    0.1240   2.5438
# ...

# %%
# Adam.isna().sum()

# %%
all_data = pd.concat([Max, Kom, Adam], axis=0)
all_data.reset_index(inplace=True, drop=True)
all_data
# Out:
#        MEDIAN  DPHI_DOL  DPHI_LIM  DPHI_SAN  NPHI_DOL  NPHI_LIM         U  \
# 0    2955.550   0.36248   0.31028   0.28520   0.05057   0.11829  10.17545
# 1    2965.050   0.24959   0.18816   0.15863   0.02891   0.08250   9.59309
# 2    2965.230   0.24675   0.18508   0.15544   0.02342   0.07184  12.66823
# 3    2967.550   0.30755   0.25086   0.22362   0.02352   0.07203  15.24708
# 4    2968.335   0.23536   0.17276   0.14268   0.01959   0.06391  13.70019
# ..        ...       ...       ...       ...       ...       ...       ...
# 116  2874.545   0.21380   0.14940   0.11850   0.05560   0.06490  20.47120
# 117  2884.395   0.18420   0.11740   0.08540   0.07080   0.08140  18.60500
# 118  2897.640   0.22380   0.16020   0.12970   0.08140   0.09340  29.36250
# 119  2908.700   0.17580   0.10840   0.07590   0.04310   0.05100  22.27600
# 120  2919.780   0.12460   0.05290   0.01850   0.15600   0.17630   5.76270
#
#           TH        RhoB         GR           Vp           Vs            AI  \
# ...

# %%
feature_vectors = all_data.drop(['TOC','Well','MEDIAN'], axis=1)
label_vectors   = all_data.filter(['TOC'])
well_vectors    = all_data.filter(['Well'])
depth_vectors   = all_data.filter(['MEDIAN'])

# %%
scaler = preprocessing.MinMaxScaler().fit(feature_vectors)
scaled_features = scaler.transform(feature_vectors)

# %%
df_scaled_features = pd.DataFrame(scaled_features, columns = ['DPHI_DOL','DPHI_LIM','DPHI_SAN','NPHI_DOL',
                                                              'NPHI_LIM','U','TH','RhoB','GR','Vp','Vs','AI','SI'])
scaled_features_with_well_name = pd.concat([depth_vectors,df_scaled_features, label_vectors, well_vectors], axis = 1)
scaled_features_with_well_name
# Out:
#        MEDIAN  DPHI_DOL  DPHI_LIM  DPHI_SAN  NPHI_DOL  NPHI_LIM         U  \
# 0    2955.550  1.000000  1.000000  1.000000  0.335949  0.510584  0.280047
# 1    2965.050  0.650149  0.650166  0.650166  0.215415  0.350076  0.263934
# 2    2965.230  0.641347  0.641343  0.641349  0.184864  0.302269  0.349019
# 3    2967.550  0.829769  0.829781  0.829795  0.185420  0.303121  0.420372
# 4    2968.335  0.606049  0.606050  0.606081  0.163550  0.266706  0.377572
# ..        ...       ...       ...       ...       ...       ...       ...
# 116  2874.545  0.539234  0.539131  0.539248  0.363940  0.271145  0.564916
# 117  2884.395  0.447502  0.447462  0.447761  0.448525  0.345143  0.513281
# 118  2897.640  0.570224  0.570070  0.570205  0.507513  0.398960  0.810926
# 119  2908.700  0.421470  0.421680  0.421504  0.294380  0.208808  0.614853
# 120  2919.780  0.262799  0.262691  0.262852  0.922649  0.770742  0.157952
#
#            TH      RhoB        GR        Vp        Vs        AI        SI  \
# ...

# %% [markdown]
# # Machine Learning Part #1
# ### Training and Testing using the 3 wells

# %%
# from sklearn.model_selection import train_test_split
# x = scaled_features_with_well_name.drop(['TOC','Well','MEDIAN'],axis=1)
# y = scaled_features_with_well_name['TOC']

# xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state = 123)

# %%
# x

# %%
# from sklearn import metrics
# def print_evaluate(true, predicted):  
#     mae = metrics.mean_absolute_error(true, predicted)
#     mse = metrics.mean_squared_error(true, predicted)
#     rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
#     r2_square = metrics.r2_score(true, predicted)
#     print('MAE:', mae)
#     print('MSE:', mse)
#     print('RMSE:', rmse)
#     print('R2 Square', r2_square)
#     print('__________________________________')
    
# def evaluate(true, predicted):
#     mae = metrics.mean_absolute_error(true, predicted)
#     mse = metrics.mean_squared_error(true, predicted)
#     rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
#     r2_square = metrics.r2_score(true, predicted)
#     return mae, mse, rmse, r2_square

# %%
# from sklearn.ensemble import RandomForestRegressor

# rf_reg = RandomForestRegressor(n_estimators=1000, random_state = 123)
# rf_reg.fit(xtrain, ytrain)

# test_pred = rf_reg.predict(xtest)
# train_pred = rf_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# from sklearn.svm import SVR

# svm_reg = SVR(kernel='rbf', C=100, epsilon=0.1)
# svm_reg.fit(xtrain, ytrain)

# test_pred = svm_reg.predict(xtest)
# train_pred = svm_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# from xgboost import XGBRegressor

# xgb_reg = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
# xgb_reg.fit(xtrain, ytrain)

# test_pred = xgb_reg.predict(xtest)
# train_pred = xgb_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# from skelm import ELMRegressor
# elm_reg = ELMRegressor(alpha=1e-07, 
#                          batch_size=None, 
#                          include_original_features=False, 
#                          n_neurons=980, 
# #                          ufunc='tanh',                         
# #                          ufunc='sigm',                         
#                          ufunc='relu',                         
# #                          ufunc='lin',                          
#                          density=None, 
#                          pairwise_metric=None, 
#                          random_state=123)
# elm_reg.fit(xtrain,ytrain)

# test_pred = elm_reg.predict(xtest)
# train_pred = elm_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# x_train = xtrain.to_numpy()
# y_train = ytrain.to_numpy()
# x_test = xtest.to_numpy()
# y_test = ytest.to_numpy()

# # Initialize the text regressor.
# reg = ak.StructuredDataRegressor(max_trials=100, overwrite=True)

# # Feed the structured data regressor with training data.
# reg.fit(x_train, y_train, epochs=100)

# # Predict with the best model.
# predicted_y = reg.predict(x_test)

# # Evaluate the best model with testing data.
# print(reg.evaluate(x_test, y_test))

# %%
# model = reg.export_model()
# model.summary()

# %%
# test_pred = reg.predict(x_test)
# train_pred = reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# # x_train = xtrain.to_numpy()
# # y_train = ytrain.to_numpy()
# # x_test = xtest.to_numpy()
# # y_test = ytest.to_numpy()

# # Initialize the text regressor.
# reg = ak.StructuredDataRegressor(max_trials=10, overwrite=True)

# # Feed the structured data regressor with training data.
# reg.fit(x_train, y_train, epochs=10)

# # Predict with the best model.
# predicted_y = reg.predict(x_test)

# # Evaluate the best model with testing data.
# print(reg.evaluate(x_test, y_test))

# %%
# model = reg.export_model()
# model.summary()

# %%
# test_pred = reg.predict(x_test)
# train_pred = reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# y_pred_all_1 = estimator.predict(well_input)

# %% [markdown]
# # Machine Learning Part #2
#
# ### Predicting MxAdam, by learning from Maxhamish and Komie

# %%
# blind = scaled_features_with_well_name[scaled_features_with_well_name['Well'] == 'MxAdam']
# training_data = scaled_features_with_well_name[scaled_features_with_well_name['Well'] != 'MxAdam']

# %%
# blind_with_well = blind['MEDIAN']
# blind_toc = blind['TOC']
# blind = blind.drop(['TOC','Well','MEDIAN'],axis=1)

# %%
# from sklearn.model_selection import train_test_split
# x = training_data.drop(['TOC','Well','MEDIAN'],axis=1)
# y = training_data['TOC']

# xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state = 123)

# %%
# from sklearn.ensemble import RandomForestRegressor

# rf_reg = RandomForestRegressor(n_estimators=1000, random_state = 123)
# rf_reg.fit(xtrain, ytrain)

# test_pred = rf_reg.predict(xtest)
# train_pred = rf_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_1 = rf_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_1)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_1)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from sklearn.svm import SVR

# svm_reg = SVR(kernel='rbf', C=100, epsilon=0.1)
# svm_reg.fit(xtrain, ytrain)

# test_pred = svm_reg.predict(xtest)
# train_pred = svm_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_2 = svm_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_2)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_2)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from xgboost import XGBRegressor

# xgb_reg = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
# xgb_reg.fit(xtrain, ytrain)

# test_pred = xgb_reg.predict(xtest)
# train_pred = xgb_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_3 = xgb_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_3)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_3)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from skelm import ELMRegressor
# elm_reg = ELMRegressor(alpha=1e-07, 
#                          batch_size=None, 
#                          include_original_features=False, 
#                          n_neurons=980, 
# #                          ufunc='tanh',                         
# #                          ufunc='sigm',                         
#                          ufunc='relu',                         
# #                          ufunc='lin',                          
#                          density=None, 
#                          pairwise_metric=None, 
#                          random_state=123)
# elm_reg.fit(xtrain,ytrain)

# test_pred = elm_reg.predict(xtest)
# train_pred = elm_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_4 = elm_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_4)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_4)
# print('Pearsons correlation: %.3f' % corr)

# %%
# x_train = xtrain.to_numpy()
# y_train = ytrain.to_numpy()
# x_test = xtest.to_numpy()
# y_test = ytest.to_numpy()

# # Initialize the text regressor.
# reg = ak.StructuredDataRegressor(max_trials=100, overwrite=True)

# # Feed the structured data regressor with training data.
# reg.fit(x_train, y_train, epochs=100)

# # Predict with the best model.
# predicted_y = reg.predict(x_test)

# # Evaluate the best model with testing data.
# print(reg.evaluate(x_test, y_test))

# %%
# model = reg.export_model()
# model.summary()

# %%
# test_pred = reg.predict(x_test)
# train_pred = reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# TOC_pred_5 = reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_5)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_5)
# print('Pearsons correlation: %.3f' % corr)

# %%
# # Initialize the text regressor.
# reg = ak.StructuredDataRegressor(max_trials=10, overwrite=True)

# # Feed the structured data regressor with training data.
# reg.fit(x_train, y_train, epochs=10)

# # Predict with the best model.
# predicted_y = reg.predict(x_test)

# # Evaluate the best model with testing data.
# print(reg.evaluate(x_test, y_test))

# %%
# model = reg.export_model()
# model.summary()

# %%
# test_pred = reg.predict(x_test)
# train_pred = reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# TOC_pred_6 = reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_6)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_6)
# print('Pearsons correlation: %.3f' % corr)

# %%
# plt.subplot(1, 6, 1)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_1,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("RF Reg")

# # fig.savefig('Vp_pred_1.png', dpi=100)

# plt.subplot(1, 6, 2)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_2,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("SVM Reg")

# plt.subplot(1, 6, 3)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_3,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("XGB Reg")

# plt.subplot(1, 6, 4)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_4,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("ELM Reg")

# plt.subplot(1, 6, 5)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_5,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("AutoML FF Reg #1")

# plt.subplot(1, 6, 6)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_6,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("AutoML FF Reg #2")

# plt.subplots_adjust(wspace=0.5)
# fig = plt.gcf()
# fig.set_size_inches(18, 6)

# %%
# plt.subplot(2, 3, 1)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_1,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("RF Reg", fontsize=10)

# plt.subplot(2, 3, 2)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_2,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("SVM Reg", fontsize=10)

# plt.subplot(2, 3, 3)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_3,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("XGB Reg", fontsize=10)

# plt.subplot(2, 3, 4)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_4,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("ELM Reg", fontsize=10)

# plt.subplot(2, 3, 5)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_5,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("AutoML FF Reg #1", fontsize=10)

# plt.subplot(2, 3, 6)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_6,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("AutoML FF Reg #2", fontsize=10)

# plt.subplots_adjust(wspace=0.5,hspace=0.5)
# fig = plt.gcf()
# fig.set_size_inches(10, 6)

# %% [markdown]
# # Machine Learning Part #3
#
# ### Predicting Komie, by learning from Maxhamish and MxAdam

# %%
# blind = scaled_features_with_well_name[scaled_features_with_well_name['Well'] == 'Komie']
# training_data = scaled_features_with_well_name[scaled_features_with_well_name['Well'] != 'Komie']

# %%
# blind_with_well = blind['MEDIAN']
# blind_toc = blind['TOC']
# blind = blind.drop(['TOC','Well','MEDIAN'],axis=1)

# %%
# from sklearn.model_selection import train_test_split
# x = training_data.drop(['TOC','Well','MEDIAN'],axis=1)
# y = training_data['TOC']

# xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state = 123)

# %%
# from sklearn.ensemble import RandomForestRegressor

# rf_reg = RandomForestRegressor(n_estimators=1000, random_state = 123)
# rf_reg.fit(xtrain, ytrain)

# test_pred = rf_reg.predict(xtest)
# train_pred = rf_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_1 = rf_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_1)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_1)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from sklearn.svm import SVR

# svm_reg = SVR(kernel='rbf', C=100, epsilon=0.1)
# svm_reg.fit(xtrain, ytrain)

# test_pred = svm_reg.predict(xtest)
# train_pred = svm_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_2 = svm_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_2)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_2)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from xgboost import XGBRegressor

# xgb_reg = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
# xgb_reg.fit(xtrain, ytrain)

# test_pred = xgb_reg.predict(xtest)
# train_pred = xgb_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_3 = xgb_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_3)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_3)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from skelm import ELMRegressor
# elm_reg = ELMRegressor(alpha=1e-07, 
#                          batch_size=None, 
#                          include_original_features=False, 
#                          n_neurons=980, 
# #                          ufunc='tanh',                         
# #                          ufunc='sigm',                         
#                          ufunc='relu',                         
# #                          ufunc='lin',                          
#                          density=None, 
#                          pairwise_metric=None, 
#                          random_state=123)
# elm_reg.fit(xtrain,ytrain)

# test_pred = elm_reg.predict(xtest)
# train_pred = elm_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_4 = elm_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_4)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_4)
# print('Pearsons correlation: %.3f' % corr)

# %%
# x_train = xtrain.to_numpy()
# y_train = ytrain.to_numpy()
# x_test = xtest.to_numpy()
# y_test = ytest.to_numpy()

# # Initialize the text regressor.
# reg = ak.StructuredDataRegressor(max_trials=100, overwrite=True)

# # Feed the structured data regressor with training data.
# reg.fit(x_train, y_train, epochs=100)

# # Predict with the best model.
# predicted_y = reg.predict(x_test)

# # Evaluate the best model with testing data.
# print(reg.evaluate(x_test, y_test))

# %%
# model = reg.export_model()
# model.summary()

# %%
# test_pred = reg.predict(x_test)
# train_pred = reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# TOC_pred_5 = reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_5)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_5)
# print('Pearsons correlation: %.3f' % corr)

# %%
# # Initialize the text regressor.
# reg = ak.StructuredDataRegressor(max_trials=10, overwrite=True)

# # Feed the structured data regressor with training data.
# reg.fit(x_train, y_train, epochs=10)

# # Predict with the best model.
# predicted_y = reg.predict(x_test)

# # Evaluate the best model with testing data.
# print(reg.evaluate(x_test, y_test))

# %%
# model = reg.export_model()
# model.summary()

# %%
# test_pred = reg.predict(x_test)
# train_pred = reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# TOC_pred_6 = reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_6)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_6)
# print('Pearsons correlation: %.3f' % corr)

# %%
# plt.subplot(1, 6, 1)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_1,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("RF Reg")

# # fig.savefig('Vp_pred_1.png', dpi=100)

# plt.subplot(1, 6, 2)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_2,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("SVM Reg")

# plt.subplot(1, 6, 3)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_3,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("XGB Reg")

# plt.subplot(1, 6, 4)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_4,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("ELM Reg")

# plt.subplot(1, 6, 5)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_5,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("AutoML FF Reg #1")

# plt.subplot(1, 6, 6)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_6,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("AutoML FF Reg #2")

# plt.subplots_adjust(wspace=0.5)
# fig = plt.gcf()
# fig.set_size_inches(18, 6)

# %%
# plt.subplot(2, 3, 1)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_1,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("RF Reg", fontsize=10)

# plt.subplot(2, 3, 2)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_2,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("SVM Reg", fontsize=10)

# plt.subplot(2, 3, 3)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_3,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("XGB Reg", fontsize=10)

# plt.subplot(2, 3, 4)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_4,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("ELM Reg", fontsize=10)

# plt.subplot(2, 3, 5)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_5,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("AutoML FF Reg #1", fontsize=10)

# plt.subplot(2, 3, 6)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_6,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("AutoML FF Reg #2", fontsize=10)

# plt.subplots_adjust(wspace=0.5,hspace=0.5)
# fig = plt.gcf()
# fig.set_size_inches(10, 6)

# %% [markdown]
# # Machine Learning Part #4
#
# ### Predicting Maxhamish, by learning from Komie and MxAdam

# %%
# blind = scaled_features_with_well_name[scaled_features_with_well_name['Well'] == 'Maxhamish']
# training_data = scaled_features_with_well_name[scaled_features_with_well_name['Well'] != 'Maxhamish']

# %%
# blind_with_well = blind['MEDIAN']
# blind_toc = blind['TOC']
# blind = blind.drop(['TOC','Well','MEDIAN'],axis=1)

# %%
# from sklearn.model_selection import train_test_split
# x = training_data.drop(['TOC','Well','MEDIAN'],axis=1)
# y = training_data['TOC']

# xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state = 123)

# %%
# from sklearn.ensemble import RandomForestRegressor

# rf_reg = RandomForestRegressor(n_estimators=1000, random_state = 123)
# rf_reg.fit(xtrain, ytrain)

# test_pred = rf_reg.predict(xtest)
# train_pred = rf_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_1 = rf_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_1)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_1)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from sklearn.svm import SVR

# svm_reg = SVR(kernel='rbf', C=100, epsilon=0.1)
# svm_reg.fit(xtrain, ytrain)

# test_pred = svm_reg.predict(xtest)
# train_pred = svm_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_2 = svm_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_2)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_2)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from xgboost import XGBRegressor

# xgb_reg = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
# xgb_reg.fit(xtrain, ytrain)

# test_pred = xgb_reg.predict(xtest)
# train_pred = xgb_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_3 = xgb_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_3)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_3)
# print('Pearsons correlation: %.3f' % corr)

# %%
# from skelm import ELMRegressor
# elm_reg = ELMRegressor(alpha=1e-07, 
#                          batch_size=None, 
#                          include_original_features=False, 
#                          n_neurons=980, 
# #                          ufunc='tanh',                         
# #                          ufunc='sigm',                         
#                          ufunc='relu',                         
# #                          ufunc='lin',                          
#                          density=None, 
#                          pairwise_metric=None, 
#                          random_state=123)
# elm_reg.fit(xtrain,ytrain)

# test_pred = elm_reg.predict(xtest)
# train_pred = elm_reg.predict(xtrain)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(ytest, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(ytrain, train_pred)

# %%
# TOC_pred_4 = elm_reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_4)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_4)
# print('Pearsons correlation: %.3f' % corr)

# %%
# x_train = xtrain.to_numpy()
# y_train = ytrain.to_numpy()
# x_test = xtest.to_numpy()
# y_test = ytest.to_numpy()

# split = 10
# x_val = x_train[split:]
# y_val = y_train[split:]
# x_train = x_train[:split]
# y_train = y_train[:split]

# %%
# reg = ak.StructuredDataRegressor(max_trials=100, overwrite=True)

# # Feed the structured data regressor with training data.
# reg.fit(x_train,
#         y_train,
#         # Use your own validation set.
#         validation_data=(x_val,y_val),
#         epochs=100,
#        )

# # Predict with the best model.
# predicted_y = reg.predict(x_test)

# # Evaluate the best model with testing data.
# print(reg.evaluate(x_test, y_test))

# %%
# model = reg.export_model()
# model.summary()

# %%
# test_pred = reg.predict(x_test)
# train_pred = reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# TOC_pred_5 = reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_5)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_5)
# print('Pearsons correlation: %.3f' % corr)

# %%
# reg = ak.StructuredDataRegressor(max_trials=10, overwrite=True)

# # Feed the structured data regressor with training data.
# reg.fit(x_train,
#         y_train,
#         # Use your own validation set.
#         validation_data=(x_val,y_val),
#         epochs=10,
#        )

# # Predict with the best model.
# predicted_y = reg.predict(x_test)

# # Evaluate the best model with testing data.
# print(reg.evaluate(x_test, y_test))

# %%
# model = reg.export_model()
# model.summary()

# %%
# test_pred = reg.predict(x_test)
# train_pred = reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# TOC_pred_6 = reg.predict(blind)
# print_evaluate(blind_toc, TOC_pred_6)

# from scipy.stats import pearsonr
# corr, _ = pearsonr(blind_toc, TOC_pred_6)
# print('Pearsons correlation: %.3f' % corr)

# %%
# plt.subplot(1, 6, 1)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_1,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("RF Reg")

# # fig.savefig('Vp_pred_1.png', dpi=100)

# plt.subplot(1, 6, 2)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_2,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("SVM Reg")

# plt.subplot(1, 6, 3)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_3,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("XGB Reg")

# plt.subplot(1, 6, 4)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_4,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("ELM Reg")

# plt.subplot(1, 6, 5)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_5,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("AutoML FF Reg #1")

# plt.subplot(1, 6, 6)
# plt.plot(blind_toc,blind_with_well,label="Measured TOC")
# plt.plot(TOC_pred_6,blind_with_well,label="Predicted TOC")
# plt.legend()
# plt.gca().invert_yaxis()

# # plt.gca().set_ylim([4.2, 1])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC")
# # plt.ylabel("Depth")
# plt.legend(fontsize=6)
# plt.title("AutoML FF Reg #2")

# plt.subplots_adjust(wspace=0.5)
# fig = plt.gcf()
# fig.set_size_inches(18, 6)

# %%
# plt.subplot(2, 3, 1)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_1,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("RF Reg", fontsize=10)

# plt.subplot(2, 3, 2)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_2,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("SVM Reg", fontsize=10)

# plt.subplot(2, 3, 3)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_3,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("XGB Reg", fontsize=10)

# plt.subplot(2, 3, 4)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_4,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("ELM Reg", fontsize=10)

# plt.subplot(2, 3, 5)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_5,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("AutoML FF Reg #1", fontsize=10)

# plt.subplot(2, 3, 6)
# plt.axline([0, 0], [1, 1])
# plt.plot(blind_toc,TOC_pred_6,"bo",markersize=4)
# plt.gca().set_ylim([0, 10])
# plt.gca().set_xlim([0, 10])
# plt.xticks(np.arange(0, 11, 1))
# plt.yticks(np.arange(0, 11, 1))
# plt.grid()
# plt.xlabel("TOC Actual", fontsize=10)
# plt.ylabel("TOC Predicted", fontsize=10)
# plt.title("AutoML FF Reg #2", fontsize=10)

# plt.subplots_adjust(wspace=0.5,hspace=0.5)
# fig = plt.gcf()
# fig.set_size_inches(10, 6)

# %% [markdown]
# # After analyzing the results: FF#2 is the most robust algorithm for TOC prediction of the dataset

# %%
from sklearn.model_selection import train_test_split
x = scaled_features_with_well_name.drop(['TOC','Well','MEDIAN'],axis=1)
y = scaled_features_with_well_name['TOC']

xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state = 123)

# %%
xtrain
# Out:
#      DPHI_DOL  DPHI_LIM  DPHI_SAN  NPHI_DOL  NPHI_LIM         U        TH  \
# 28   0.512489  0.512461  0.512493  0.256038  0.408647  0.255935  0.572108
# 38   0.506725  0.506703  0.506744  0.324597  0.496995  0.203589  0.472880
# 19   0.447998  0.447978  0.448038  0.325431  0.497982  0.183726  0.594097
# 113  0.172617  0.172453  0.172471  0.663328  0.536192  0.068889  0.673506
# 77   0.628858  0.628853  0.628883  0.189872  0.310297  0.652937  0.053996
# ..        ...       ...       ...       ...       ...       ...       ...
# 102  0.212904  0.212845  0.212825  1.000000  0.839806  0.174066  0.684902
# 98   0.444775  0.431076  0.431122  0.289371  0.491031  0.293647  0.473362
# 92   0.141595  0.126246  0.126313  0.722148  0.859494  0.021111  0.939593
# 66   0.468514  0.468517  0.468546  0.279744  0.440578  0.539434  0.392904
# 109  0.000000  0.000000  0.000000  0.750139  0.614225  0.043180  0.771099
#
#          RhoB        GR        Vp        Vs        AI        SI
# ...

# %%
import sklearn.metrics as metrics

def print_evaluate(true, predicted):  
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    print('MAE:', mae)
    print('MSE:', mse)
    print('RMSE:', rmse)
    print('R2 Square', r2_square)
    print('__________________________________')
    
def evaluate(true, predicted):
    mae = metrics.mean_absolute_error(true, predicted)
    mse = metrics.mean_squared_error(true, predicted)
    rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
    r2_square = metrics.r2_score(true, predicted)
    return mae, mse, rmse, r2_square

# %%
x_train = xtrain.to_numpy()
y_train = ytrain.to_numpy()
x_test = xtest.to_numpy()
y_test = ytest.to_numpy()

# Initialize the text regressor.
reg = ak.StructuredDataRegressor(max_trials=100, overwrite=True)

# Feed the structured data regressor with training data.
reg.fit(x_train, y_train, epochs=100)

# Predict with the best model.
predicted_y = reg.predict(x_test)

# Evaluate the best model with testing data.
print(reg.evaluate(x_test, y_test))
# Out:
# Trial 82 Complete [00h 00m 05s]
# val_loss: 2.2971928119659424
#
# Best val_loss So Far: 2.1198952198028564
# Total elapsed time: 00h 10m 22s
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/100
# 3/3 [==============================] - 0s 2ms/step - loss: 9.6535 - mean_squared_error: 9.6535
# Epoch 2/100
# 3/3 [==============================] - 0s 3ms/step - loss: 7.5838 - mean_squared_error: 7.5838
# Epoch 3/100
# 3/3 [==============================] - 0s 4ms/step - loss: 6.1303 - mean_squared_error: 6.1303
# Epoch 4/100
# 3/3 [==============================] - 0s 4ms/step - loss: 4.8135 - mean_squared_error: 4.8135
# Epoch 5/100
# 3/3 [==============================] - 0s 3ms/step - loss: 3.3077 - mean_squared_error: 3.3077
# Epoch 6/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6505 - mean_squared_error: 2.6505
# Epoch 7/100
# 3/3 [==============================] - 0s 4ms/step - loss: 2.8366 - mean_squared_error: 2.8366
# Epoch 8/100
# ...

# %%
model = reg.export_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 13)]              0
#
#  multi_category_encoding (Mu  (None, 13)               0
#  ltiCategoryEncoding)
#
#  normalization (Normalizatio  (None, 13)               27
#  n)
#
#  dense (Dense)               (None, 1024)              14336
#
#  re_lu (ReLU)                (None, 1024)              0
#
#  dense_1 (Dense)             (None, 32)                32800
#
#  re_lu_1 (ReLU)              (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  regression_head_1 (Dense)   (None, 1)                 33
#
# ...
# Total params: 47,196
# Trainable params: 47,169
# Non-trainable params: 27
# _________________________________________________________________

# %%
test_pred = reg.predict(x_test)
train_pred = reg.predict(x_train)

print('Test set evaluation:\n_____________________________________')
print_evaluate(y_test, test_pred)

print('Train set evaluation:\n_____________________________________')
print_evaluate(y_train, train_pred)
# Out:
# ...
# 3/3 [==============================] - 0s 3ms/step
# Test set evaluation:
# _____________________________________
# MAE: 1.0817552019846355
# MSE: 2.2433093562571274
# RMSE: 1.497768124997033
# R2 Square 0.052093390732108835
# __________________________________
# Train set evaluation:
# _____________________________________
# MAE: 0.6469566297854058
# MSE: 0.7110451662069107
# RMSE: 0.8432349412867749
# R2 Square 0.741308199501328
# __________________________________

# %%
## AutoKeras cannot use pickle
# import pickle
# file_name = "FF2_reg.pkl"

# # save
# pickle.dump(reg, open(file_name, "wb"))

# # load
# ff2_model_loaded = pickle.load(open(file_name, "rb"))

# %%
# This one works!
# try:
#     model.save("model_autokeras_ff2", save_format="tf")
# except Exception:
#     model.save("model_autokeras_ff2.h5")

# %%
# This one works! (The original model_autokeras was using Standard scaler, my bad! so it was FF4. Now this is FF2)
try:
    model.save("model_autokeras_ff2_new", save_format="tf")
except Exception:
    model.save("model_autokeras_ff2_new.h5")
# Out:
# INFO:tensorflow:Assets written to: model_autokeras_ff2_new\assets

# %%
# from tensorflow.keras.models import load_model
# loaded_model = load_model("model_autokeras_ff2", custom_objects=ak.CUSTOM_OBJECTS)

# %%
from tensorflow.keras.models import load_model
loaded_model = load_model("model_autokeras_ff2_new", custom_objects=ak.CUSTOM_OBJECTS)

# %%
predicted_y = loaded_model.predict(tf.expand_dims(x_test, -1))
print(predicted_y)
# Out:
# 1/1 [==============================] - 0s 83ms/step
# [[2.6678817 ]
#  [1.4629183 ]
#  [3.932389  ]
#  [5.2260895 ]
#  [2.8618925 ]
#  [2.068276  ]
#  [5.776912  ]
#  [3.6008122 ]
#  [2.1814575 ]
#  [3.3634944 ]
#  [2.6277273 ]
#  [5.139781  ]
#  [2.8006678 ]
#  [7.5213456 ]
#  [2.4240062 ]
#  [2.5314176 ]
#  [5.558266  ]
#  [2.9251983 ]
#  [1.6062241 ]
#  [3.0867488 ]
#  [2.378532  ]
#  [0.31927422]
#  [4.3310366 ]
#  [2.309601  ]
#  [2.50264   ]]

# %%
measured_TOC = scaled_features_with_well_name

# %%
measured_TOC_Maxhamish = measured_TOC[measured_TOC['Well']=='Maxhamish']
measured_TOC_McAdam    = measured_TOC[measured_TOC['Well']=='MxAdam']
measured_TOC_Komie     = measured_TOC[measured_TOC['Well']=='Komie']

# %%
measured_TOC_Maxhamish
# Out:
#       MEDIAN  DPHI_DOL  DPHI_LIM  DPHI_SAN  NPHI_DOL  NPHI_LIM         U  \
# 0   2955.550  1.000000  1.000000  1.000000  0.335949  0.510584  0.280047
# 1   2965.050  0.650149  0.650166  0.650166  0.215415  0.350076  0.263934
# 2   2965.230  0.641347  0.641343  0.641349  0.184864  0.302269  0.349019
# 3   2967.550  0.829769  0.829781  0.829795  0.185420  0.303121  0.420372
# 4   2968.335  0.606049  0.606050  0.606081  0.163550  0.266706  0.377572
# ..       ...       ...       ...       ...       ...       ...       ...
# 80  3076.050  0.292767  0.292741  0.292786  0.103728  0.155126  0.537716
# 81  3077.050  0.124923  0.124900  0.124959  0.000000  0.000000  0.231622
# 82  3078.035  0.158609  0.158588  0.158651  0.033723  0.037761  0.091934
# 83  3080.550  0.113425  0.113412  0.113460  0.025654  0.028209  0.089357
# 84  3083.020  0.099386  0.099376  0.099420  0.030384  0.033770  0.077390
#
#           TH      RhoB        GR        Vp        Vs        AI        SI  \
# ...

# %%
measured_TOC_Maxhamish.to_csv('measured_TOC_Maxhamish.csv', index=False)
measured_TOC_McAdam.to_csv('measured_TOC_McAdam.csv', index=False)
measured_TOC_Komie.to_csv('measured_TOC_Komie.csv', index=False)

# %%
# from xgboost import XGBRegressor

# xgb_reg = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
# xgb_reg.fit(x_train, y_train)

# test_pred = xgb_reg.predict(x_test)
# train_pred = xgb_reg.predict(x_train)

# print('Test set evaluation:\n_____________________________________')
# print_evaluate(y_test, test_pred)

# print('Train set evaluation:\n_____________________________________')
# print_evaluate(y_train, train_pred)

# %%
# Not using this, keep it as is.
# # save to JSON
# xgb_reg.save_model("model_XGB_TOC.json")
# # save to text format
# xgb_reg.save_model("model_XGB_TOC.txt")

# %%
# # Use this one..
# import pickle
# file_name = "xgb_reg.pkl"

# # save
# pickle.dump(xgb_reg, open(file_name, "wb"))

# # load
# xgb_model_loaded = pickle.load(open(file_name, "rb"))

# %%
# test_pred = xgb_model_loaded.predict(xtest)
# test_pred
